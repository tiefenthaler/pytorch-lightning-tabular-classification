# %%
import os
import yaml
import mlflow
from mlflow.tracking import MlflowClient

# %%
EXPERIMENT_NAME = "AutoPackagingCategories"

with open('../env_vars.yml', 'r') as file:
    env_vars = yaml.safe_load(file)

project_dir = env_vars['project_directory']

mlflow.set_tracking_uri("file://" + project_dir + "/mlruns")

experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)
EXPERIMENT_ID = experiment.experiment_id

# %%
# EXPERIMENT_NAME = ""
# mlflow.set_tracking_uri("file://" + project_dir + "/mlruns")

client = MlflowClient()

# Retrieve Experiment information
EXPERIMENT_ID = client.get_experiment_by_name(EXPERIMENT_NAME).experiment_id

df_experiment = mlflow.search_runs(experiment_ids=EXPERIMENT_ID, order_by=["start_time DESC"])

# View Runs information
df_experiment

# Retrieve Artifact from best run
# best_run_id = DF.sort_values("Metrics", ascending=False).iloc[0]["Run ID"]
# best_model_path = client.download_artifacts(best_run_id, "classifier")
# best_model = mlflow.sklearn.load_model(best_model_path)

# Delete runs (DO NOT USE UNLESS CERTAIN)
# for run_id in ALL_RUNS_ID:
#     client.delete_run(run_id)

# Delete experiment (DO NOT USE UNLESS CERTAIN)
# client.delete_experiment(EXPERIMENT_ID)
# Out:
#                              run_id       experiment_id    status  \
# 0  da232a386c6848909a2646a95b3799d8  873449102029119797  FINISHED
# 1  c1dddc5bb2d54d449c5b9597791c606f  873449102029119797  FINISHED
# 2  3417a933ab3445a897cf71ea470e805b  873449102029119797  FINISHED
#
#                                         artifact_uri  \
# 0  file:///Users/dat/Library/CloudStorage/GoogleD...
# 1  file:///Users/dat/Library/CloudStorage/GoogleD...
# 2  file:///Users/dat/Library/CloudStorage/GoogleD...
#
#                         start_time                         end_time  \
# 0 2024-11-12 13:57:13.365000+00:00 2024-11-12 13:57:13.707000+00:00
# 1 2024-11-12 13:55:32.441000+00:00 2024-11-12 13:55:32.503000+00:00
# 2 2024-11-12 13:34:23.180000+00:00 2024-11-12 13:34:24.062000+00:00
#
#    metrics.Report_Test_f1_macro  metrics.TestVal_f1_macro  \
# 0                      0.009873                  0.009873
# 1                      0.009873                  0.009873
# 2                           NaN                       NaN
#
#    metrics.Train_f1_macro  metrics.Test_f1-score  metrics.Train_f1-score  \
# 0                0.009874                    NaN                     NaN
# 1                0.009874                    NaN                     NaN
# 2                     NaN               0.167076                 0.16709
#
#                                 params.model_configs  \
# 0  [('strategy', 'most_frequent'), ('random_state...
# 1  [('strategy', 'most_frequent'), ('random_state...
# 2  [('strategy', 'most_frequent'), ('random_state...
#
#                  params.preprocessing_categoric_feat  \
# 0  impute: SimpleImputer(strategy='most_frequent'...
# 1  impute: SimpleImputer(strategy='most_frequent'...
# 2  impute: SimpleImputer(strategy='most_frequent'...
#
#                    params.preprocessing_numeric_feat  \
# 0  impute: SimpleImputer(strategy='median'), log_...
# 1  impute: SimpleImputer(strategy='median'), log_...
# 2  impute: SimpleImputer(strategy='median'), log_...
#
#                              tags.mlflow.source.name tags.mlflow.user  \
# 0  /Users/dat/miniforge3/envs/py_ml_packaging_cla...              dat
# 1  /Users/dat/miniforge3/envs/py_ml_packaging_cla...              dat
# 2  /Users/dat/miniforge3/envs/py_ml_packaging_cla...              dat
#
#                                  tags.mlflow.runName tags.mlflow.source.type
# 0  run_Naive_MostFrequent_2024-11-12 14:57:13.123686                   LOCAL
# 1  run_Naive_MostFrequent_2024-11-12 14:55:32.430040                   LOCAL
# 2  run_Naive_MostFrequent_2024-11-12 14:34:22.813500                   LOCAL
