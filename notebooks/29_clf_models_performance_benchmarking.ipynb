# %%
import os
import yaml
import mlflow
from mlflow.tracking import MlflowClient

# %%
EXPERIMENT_NAME = "AutoPackagingCategories"

with open('../env_vars.yml', 'r') as file:
    config = yaml.safe_load(file)

mlflow_dir = config['mlflow_benchmark_directory']

mlflow.set_tracking_uri("file://" + mlflow_dir)

experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)
EXPERIMENT_ID = experiment.experiment_id

# %%
# EXPERIMENT_NAME = ""
# mlflow.set_tracking_uri("file://" + project_dir + "/mlruns")

client = MlflowClient()

# Retrieve Experiment information
EXPERIMENT_ID = client.get_experiment_by_name(EXPERIMENT_NAME).experiment_id

df_experiment = mlflow.search_runs(experiment_ids=EXPERIMENT_ID, order_by=["start_time DESC"])

# View Runs information
df_experiment

# Retrieve Artifact from best run
# best_run_id = DF.sort_values("Metrics", ascending=False).iloc[0]["Run ID"]
# best_model_path = client.download_artifacts(best_run_id, "classifier")
# best_model = mlflow.sklearn.load_model(best_model_path)

# Delete runs (DO NOT USE UNLESS CERTAIN)
# for run_id in ALL_RUNS_ID:
#     client.delete_run(run_id)

# Delete experiment (DO NOT USE UNLESS CERTAIN)
# client.delete_experiment(EXPERIMENT_ID)
# Out:
#                              run_id       experiment_id    status  \
# 0  37a66b109d984426977d26ca0f809fa7  973868406124262456  FINISHED
# 1  e70c8e40e5804580b64d3276b784f8bd  973868406124262456  FINISHED
# 2  7702fb4860954857915280faf17e5a3a  973868406124262456  FINISHED
# 3  77088ce95f1c40e0bb49b0859587c1b8  973868406124262456  FINISHED
# 4  cc9d4b5818194531983358b0a2f15bce  973868406124262456  FINISHED
# 5  83fe2ee2cd794747a6dfeee8a82521ef  973868406124262456  FINISHED
# 6  574f156890c34435bf033f0b11b9e0d0  973868406124262456    FAILED
# 7  af6f098cc7ee4b86bfe24f167d3a5bb5  973868406124262456  FINISHED
# 8  34bf2d3f302941d9a427a2f227377dcd  973868406124262456  FINISHED
# 9  e15cb75efa274375aac5efe58f5ceff6  973868406124262456  FINISHED
#
#                                         artifact_uri  \
# 0  file:///Users/dat/Library/CloudStorage/GoogleD...
# 1  file:///Users/dat/Library/CloudStorage/GoogleD...
# 2  file:///Users/dat/Library/CloudStorage/GoogleD...
# 3  file:///Users/dat/Library/CloudStorage/GoogleD...
# 4  file:///Users/dat/Library/CloudStorage/GoogleD...
# 5  file:///Users/dat/Library/CloudStorage/GoogleD...
# 6  file:///Users/dat/Library/CloudStorage/GoogleD...
# 7  file:///Users/dat/Library/CloudStorage/GoogleD...
# 8  file:///Users/dat/Library/CloudStorage/GoogleD...
# 9  file:///Users/dat/Library/CloudStorage/GoogleD...
#
#                         start_time                         end_time  \
# 0 2024-11-13 00:02:48.096000+00:00 2024-11-13 00:02:48.149000+00:00
# 1 2024-11-12 23:11:52.469000+00:00 2024-11-12 23:11:52.734000+00:00
# 2 2024-11-12 23:10:09.676000+00:00 2024-11-12 23:10:09.731000+00:00
# 3 2024-11-12 22:52:15.067000+00:00 2024-11-12 22:52:15.213000+00:00
# 4 2024-11-12 18:41:28.795000+00:00 2024-11-12 18:41:28.820000+00:00
# 5 2024-11-12 15:42:07.829000+00:00 2024-11-12 15:42:07.875000+00:00
# 6 2024-11-12 15:41:54.126000+00:00 2024-11-12 15:41:54.148000+00:00
# 7 2024-11-12 15:33:28.906000+00:00 2024-11-12 15:33:28.950000+00:00
# 8 2024-11-12 14:12:23.324000+00:00 2024-11-12 14:12:23.372000+00:00
# 9 2024-11-12 14:03:20.873000+00:00 2024-11-12 14:03:20.914000+00:00
#
#    metrics.Report_Test_f1_score  metrics.Report_Test_f1_macro  \
# 0                      0.935389                      0.877422
# 1                      0.715943                      0.642828
# 2                      0.365709                      0.147572
# 3                      0.715943                      0.642828
# 4                      0.365709                      0.147572
# 5                      0.902507                      0.837624
# 6                           NaN                           NaN
# 7                      0.167076                      0.009873
# 8                      0.167076                      0.009873
# 9                           NaN                      0.009873
#
#    metrics.TestVal_f1_macro  metrics.Train_f1_macro  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# 5                       NaN                     NaN
# 6                       NaN                     NaN
# 7                  0.009873                0.009874
# 8                  0.009873                0.009874
# 9                  0.009873                0.009874
#
#                                         params.model  \
# 0  MulticlassTabularCatEmbeddingMLP(\n  (cont_nor...
# 1  <class 'sklearn.tree._classes.DecisionTreeClas...
# 2  <class 'autogluon.core.models.ensemble.weighte...
# 3  <class 'sklearn.tree._classes.DecisionTreeClas...
# 4  <class 'autogluon.core.models.ensemble.weighte...
# 5  <class 'sklearn.tree._classes.DecisionTreeClas...
# 6                                               None
# 7            <class 'sklearn.dummy.DummyClassifier'>
# 8            <class 'sklearn.dummy.DummyClassifier'>
# 9            <class 'sklearn.dummy.DummyClassifier'>
#
#                                 params.model_configs  \
# 0  dict_items([('hidden_size', 64), ('n_hidden_la...
# 1  {'ccp_alpha': 0.0, 'class_weight': {0: 0.24640...
# 2  {'use_orig_features': False, 'max_base_models'...
# 3  {'ccp_alpha': 0.0, 'class_weight': {0: 0.24640...
# 4  {'use_orig_features': False, 'max_base_models'...
# 5  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 6                                               None
# 7  dict_items([('constant', None), ('random_state...
# 8  [('strategy', 'most_frequent'), ('random_state...
# 9  [('strategy', 'most_frequent'), ('random_state...
#
#                    params.preprocessing_numeric_feat  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8  impute: SimpleImputer(strategy='median'), log_...
# 9  impute: SimpleImputer(strategy='median'), log_...
#
#                  params.preprocessing_categoric_feat  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8  impute: SimpleImputer(strategy='most_frequent'...
# 9  impute: SimpleImputer(strategy='most_frequent'...
#
#                              tags.mlflow.source.name  \
# 0  /Users/dat/miniforge3/envs/py_ml_packaging_cla...
# 1  /Users/dat/miniforge3/envs/py_ml_packaging_cla...
# 2  /Users/dat/miniforge3/envs/py_ml_packaging_cla...
# 3  /Users/dat/miniforge3/envs/py_ml_packaging_cla...
# 4  /Users/dat/miniforge3/envs/py_ml_packaging_cla...
# 5  /Users/dat/miniforge3/envs/py_ml_packaging_cla...
# 6  /Users/dat/miniforge3/envs/py_ml_packaging_cla...
# 7  /Users/dat/miniforge3/envs/py_ml_packaging_cla...
# 8  /Users/dat/miniforge3/envs/py_ml_packaging_cla...
# 9  /Users/dat/miniforge3/envs/py_ml_packaging_cla...
#
#                                  tags.mlflow.runName tags.mlflow.source.type  \
# 0        run_EmbeddingMLP_2024-11-13 01:02:47.760964                   LOCAL
# 1        run_DecisionTree_2024-11-13 00:11:52.463748                   LOCAL
# 2  run_AutoML_AutoGluonTabular_2024-11-13 00:10:0...                   LOCAL
# 3        run_DecisionTree_2024-11-12 23:52:14.527243                   LOCAL
# 4  run_AutoML_AutoGluonTabular_2024-11-12 19:41:2...                   LOCAL
# 5  run_Naive_MostFrequent_2024-11-12 16:42:07.826108                   LOCAL
# 6  run_Naive_MostFrequent_2024-11-12 16:41:53.807984                   LOCAL
# 7  run_Naive_MostFrequent_2024-11-12 16:33:28.900494                   LOCAL
# 8  run_Naive_MostFrequent_2024-11-12 15:12:23.125426                   LOCAL
# 9  run_Naive_MostFrequent_2024-11-12 15:03:20.867625                   LOCAL
#
#   tags.mlflow.user
# 0              dat
# 1              dat
# 2              dat
# 3              dat
# 4              dat
# 5              dat
# 6              dat
# 7              dat
# 8              dat
# 9              dat
